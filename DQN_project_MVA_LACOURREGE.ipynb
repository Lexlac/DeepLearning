# %% [markdown]
# **You may need to install [OpenCV](https://pypi.python.org/pypi/opencv-python) and [scikit-video](http://www.scikit-video.org/stable/).**

# %%
import keras
import numpy as np
import io
import base64
from IPython.display import HTML
import skvideo.io
import cv2
import json
from keras.optimizers import sgd, Adam
from keras.models import Sequential,model_from_json
from keras.layers.core import Dense
from keras.optimizers import sgd
from keras.layers import Conv2D, MaxPooling2D, Activation, AveragePooling2D,Reshape,BatchNormalization,Flatten,Dropout
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # MiniProject #3: Deep Reinforcement Learning

# %% [markdown]
# __Notations__: $E_p$ is the expectation under probability $p$. Please justify each of your answer and widely comment your code.

# %% [markdown]
# # Context

# %% [markdown]
# In a reinforcement learning algorithm, we modelize each step $t$ as an action $a_t$ obtained from a state $s_t$, i.e. $\{(a_{t},s_{t})_{t\leq T}\}$ having the Markov property. We consider a discount factor $\gamma \in [0,1]$ that ensures convergence. The goal is to find among all the policies $\pi$, one that maximizes the expected reward:
#
# \begin{equation*}
# R(\pi)=\sum_{t\leq T}E_{p^{\pi}}[\gamma^t r(s_{t},a_{t})] \> ,
# \end{equation*}
#
# where:
# \begin{equation*}p^{\pi}(a_{0},a_{1},s_{1},...,a_{T},s_{T})=p(a_{0})\prod_{t=1}^{T}\pi(a_{t}|s_{t})p(s_{t+1}|s_{t},a_{t}) \> .
# \end{equation*}
#
# We note the $Q$-function:
#
# \begin{equation*}Q^\pi(s,a)=E_{p^{\pi}}[\sum_{t\leq T}\gamma^{t}r(s_{t},a_{t})|s_{0}=s,a_{0}=a] \> .
# \end{equation*}
#
# Thus, the optimal Q function is:
# \begin{equation*}
# Q^*(s,a)=\max_{\pi}Q^\pi(s,a) \> .
# \end{equation*}
#
# In this project, we will apply the deep reinforcement learning techniques to a simple game: an agent will have to learn from scratch a policy that will permit it maximizing a reward.

# %% [markdown]
# ## The environment, the agent and the game

# %% [markdown]
# ### The environment

# %% [markdown]
# ```Environment``` is an abstract class that represents the states, rewards, and actions to obtain the new state.

# %%
class Environment(object):
    def __init__(self):
        pass

    def act(self, act):
        """
        One can act on the environment and obtain its reaction:
        - the new state
        - the reward of the new state
        - should we continue the game?

        :return: state, reward, game_over
        """
        pass


    def reset(self):
        """
        Reinitialize the environment to a random state and returns
        the original state

        :return: state
        """
        pass
    
    def draw(self):
        """
        Visualize in the console or graphically the current state
        """
        pass

# %% [markdown]
# The method ```act``` allows to act on the environment at a given state $s_t$ (stored internally), via action $a_t$. The method will return the new state $s_{t+1}$, the reward $r(s_{t},a_{t})$ and determines if $t\leq T$ (*game_over*).
#
# The method ```reset``` simply reinitializes the environment to a random state $s_0$.
#
# The method ```draw``` displays the current state $s_t$ (this is useful to check the behavior of the Agent).
#
# We modelize $s_t$ as a tensor, while $a_t$ is an integer.

# %% [markdown]
# ### The Agent

# %% [markdown]
# The goal of the ```Agent``` is to interact with the ```Environment``` by proposing actions $a_t$ obtained from a given state $s_t$ to attempt to maximize its __reward__ $r(s_t,a_t)$. We propose the following abstract class:

# %%
class Agent(object):
    def __init__(self, epsilon=0.1, n_action=4):
        self.epsilon = epsilon
        self.n_action = n_action
    
    def set_epsilon(self,e):
        self.epsilon = e

    def act(self,s,train=True):
        """ This function should return the next action to do:
        an integer between 0 and 4 (not included) with a random exploration of epsilon"""
        if train:
            if np.random.rand() <= self.epsilon:
                a = np.random.randint(0, self.n_action, size=1)[0]
            else:
                a = self.learned_act(s)
        else: # in some cases, this can improve the performance.. remove it if poor performances
            a = self.learned_act(s)

        return a

    def learned_act(self,s):
        """ Act via the policy of the agent, from a given state s
        it proposes an action a"""
        pass

    def reinforce(self, s, n_s, a, r, game_over_):
        """ This function is the core of the learning algorithm. 
        It takes as an input the current state s_, the next state n_s_
        the action a_ used to move from s_ to n_s_ and the reward r_.
        
        Its goal is to learn a policy.
        """
        pass

    def save(self):
        """ This function returns basic stats if applicable: the
        loss and/or the model"""
        pass

    def load(self):
        """ This function allows to restore a model"""
        pass

# %% [markdown]
# ***
# __Question 1__:
# Explain the function act. Why is ```epsilon``` essential?

# %% [markdown]
# The reason why epsilon is essential is that because it enables the agent to look for other actions that could be better or not, in other states. It acts as a decision boundary to tell if this further exploration is necessary or if the existing action (learned) is sufficient.

# %% [markdown]
# ***
# ### The Game

# %% [markdown]
# The ```Agent``` and the ```Environment``` work in an interlaced way as in the following (take some time to understand this code as it is the core of the project)
#
# ```python
#
# epoch = 300
# env = Environment()
# agent = Agent()
#
#
# # Number of won games
# score = 0
# loss = 0
#
#
# for e in range(epoch):
#     # At each epoch, we restart to a fresh game and get the initial state
#     state = env.reset()
#     # This assumes that the games will end
#     game_over = False
#
#     win = 0
#     lose = 0
#
#     while not game_over:
#         # The agent performs an action
#         action = agent.act(state)
#
#         # Apply an action to the environment, get the next state, the reward
#         # and if the games end
#         prev_state = state
#         state, reward, game_over = env.act(action)
#
#         # Update the counters
#         if reward > 0:
#             win = win + reward
#         if reward < 0:
#             lose = lose -reward
#
#         # Apply the reinforcement strategy
#         loss = agent.reinforce(prev_state, state,  action, reward, game_over)
#
#     # Save as a mp4
#     if e % 10 == 0:
#         env.draw(e)
#
#     # Update stats
#     score += win-lose
#
#     print("Epoch {:03d}/{:03d} | Loss {:.4f} | Win/lose count {}/{} ({})"
#           .format(e, epoch, loss, win, lose, win-lose))
#     agent.save()
# ```

# %% [markdown]
# # The game, *eat cheese*

# %% [markdown]
# A rat runs on an island and tries to eat as much as possible. The island is subdivided into $N\times N$ cells, in which there are cheese (+0.5) and poisonous cells (-1). The rat has a visibility of 2 cells (thus it can see $5^2$ cells). The rat is given a time $T$ to accumulate as much food as possible. It can perform 4 actions: going up, down, left, right.
#
# The goal is to code an agent to solve this task that will learn by trial and error. We propose the following environment:

# %%
class Environment(object):
    def __init__(self, grid_size=10, max_time=500, temperature=0.1):
        grid_size = grid_size+4
        self.grid_size = grid_size
        self.max_time = max_time
        self.temperature = temperature

        #board on which one plays
        self.board = np.zeros((grid_size,grid_size))
        self.position = np.zeros((grid_size,grid_size))

        # coordinate of the cat
        self.x = 0
        self.y = 1

        # self time
        self.t = 0

        self.scale=16

        self.to_draw = np.zeros((max_time+2, grid_size*self.scale, grid_size*self.scale, 3))


    def draw(self,e):
        skvideo.io.vwrite(str(e) + '.mp4', self.to_draw)

    def get_frame(self,t):
        b = np.zeros((self.grid_size,self.grid_size,3))+128
        b[self.board>0,0] = 256
        b[self.board < 0, 2] = 256
        b[self.x,self.y,:]=256
        b[-2:,:,:]=0
        b[:,-2:,:]=0
        b[:2,:,:]=0
        b[:,:2,:]=0
        
        b =  cv2.resize(b, None, fx=self.scale, fy=self.scale, interpolation=cv2.INTER_NEAREST)

        self.to_draw[t,:,:,:]=b


    def act(self, action):
        """This function returns the new state, reward and decides if the
        game ends."""

        self.get_frame(int(self.t))

        self.position = np.zeros((self.grid_size, self.grid_size))

        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:, :] = -1
        self.position[-2:, :] = -1

        self.position[self.x, self.y] = 1
        if action == 0:
            if self.x == self.grid_size-3:
                self.x = self.x-1
            else:
                self.x = self.x + 1
        elif action == 1:
            if self.x == 2:
                self.x = self.x+1
            else:
                self.x = self.x-1
        elif action == 2:
            if self.y == self.grid_size - 3:
                self.y = self.y - 1
            else:
                self.y = self.y + 1
        elif action == 3:
            if self.y == 2:
                self.y = self.y + 1
            else:
                self.y = self.y - 1
        else:
            RuntimeError('Error: action not recognized')

        self.t = self.t + 1
        reward = self.board[self.x, self.y]
        self.board[self.x, self.y] = 0
        game_over = self.t > self.max_time
        state = np.concatenate((self.board.reshape(self.grid_size, self.grid_size,1),
                        self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)
        state = state[self.x-2:self.x+3,self.y-2:self.y+3,:]

        return state, reward, game_over

    def reset(self):
        """This function resets the game and returns the initial state"""

        self.x = np.random.randint(3, self.grid_size-3, size=1)[0]
        self.y = np.random.randint(3, self.grid_size-3, size=1)[0]


        bonus = 0.5*np.random.binomial(1,self.temperature,size=self.grid_size**2)
        bonus = bonus.reshape(self.grid_size,self.grid_size)

        malus = -1.0*np.random.binomial(1,self.temperature,size=self.grid_size**2)
        malus = malus.reshape(self.grid_size, self.grid_size)

        self.to_draw = np.zeros((self.max_time+2, self.grid_size*self.scale, self.grid_size*self.scale, 3))


        malus[bonus>0]=0

        self.board = bonus + malus

        self.position = np.zeros((self.grid_size, self.grid_size))
        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:, :] = -1
        self.position[-2:, :] = -1
        self.board[self.x,self.y] = 0
        self.t = 0

        state = np.concatenate((
                               self.board.reshape(self.grid_size, self.grid_size,1),
                        self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)

        state = state[self.x - 2:self.x + 3, self.y - 2:self.y + 3, :]
        return state

# %% [markdown]
# The following elements are important because they correspond to the hyper parameters for this project:

# %%
# parameters
size = 13
T=200
temperature=0.3
epochs_train=100 # set small when debugging
epochs_test=50 # set small when debugging

# display videos
def display_videos(name):
    video = io.open(name, 'r+b').read()
    encoded = base64.b64encode(video)
    return '''<video alt="test" controls>
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))

# %% [markdown]
# __Question 2__ Explain the use of the arrays ```position``` and ```board```.

# %% [markdown]
# Positions arrays are used indicate the previous position of the rat on the board. As for the board ones, they posses information on the rewards for all the positions.

# %% [markdown]
# ## Random Agent

# %% [markdown]
# ***
# __Question 3__ Implement a random Agent (only ```learned_act``` needs to be implemented):

# %%
class RandomAgent(Agent):
    def __init__(self):
        super(RandomAgent, self).__init__()
        pass

    def learned_act(self, s):
        return np.random.randint(0, 4, size = 1)[0]

# %% [markdown]
# ***
# ***
# __Question 4__ Visualize the game moves. You need to fill in the following function for the evaluation:

# %%
def test(agent,env,epochs,prefix=''):
    # Number of won games
    score = 0
        
    for e in range(epochs):
        
        # At each epoch, we restart to a fresh game and get the initial state
        state = env.reset()
        # This assumes that the games will end
        game_over = False

        win = 0
        lose = 0

        while not game_over:
            # The agent performs an action
            action = agent.act(state)

            # Apply an action to the environment, get the next state, the reward
            # and if the games end
            prev_state = state
            state, reward, game_over = env.act(action)

            # Update the counters
            if reward > 0:
                win = win + reward
            if reward < 0:
                lose = lose -reward
        
        # Save as a mp4
        env.draw(prefix+str(e))

        # Update stats
        score = score + win-lose

        print("Win/lose count {}/{}. Average score ({})"
              .format(win, lose, score/(1+e)))
    print('Final score: '+str(score/epochs))

# %%
# Initialize the game
env = Environment(grid_size=size, max_time=T,temperature=temperature)

# Initialize the agent!
agent = RandomAgent()

test(agent,env,epochs_test,prefix='random')
HTML(display_videos('random0.mp4'))
# Out:
# Win/lose count 14.5/22.0. Average score (-7.5)
# Win/lose count 9.5/11.0. Average score (-4.5)
# Win/lose count 4.5/6.0. Average score (-3.5)
# Win/lose count 11.5/10.0. Average score (-2.25)
# Win/lose count 8.0/10.0. Average score (-2.2)
# Win/lose count 10.5/8.0. Average score (-1.4166666666666667)
# Win/lose count 11.0/14.0. Average score (-1.6428571428571428)
# Win/lose count 10.0/15.0. Average score (-2.0625)
# Win/lose count 15.0/13.0. Average score (-1.6111111111111112)
# Win/lose count 6.0/14.0. Average score (-2.25)
# Win/lose count 9.0/11.0. Average score (-2.227272727272727)
# Win/lose count 13.5/17.0. Average score (-2.3333333333333335)
# Win/lose count 8.0/14.0. Average score (-2.6153846153846154)
# Win/lose count 4.5/13.0. Average score (-3.0357142857142856)
# Win/lose count 6.5/9.0. Average score (-3.0)
# Win/lose count 5.0/12.0. Average score (-3.25)
# Win/lose count 9.0/12.0. Average score (-3.235294117647059)
# Win/lose count 6.0/18.0. Average score (-3.7222222222222223)
# Win/lose count 12.0/14.0. Average score (-3.6315789473684212)
# Win/lose count 10.0/16.0. Average score (-3.75)
# Win/lose count 11.0/6.0. Average score (-3.3333333333333335)
# Win/lose count 9.0/9.0. Average score (-3.1818181818181817)
# Win/lose count 7.5/8.0. Average score (-3.0652173913043477)
# Win/lose count 9.5/19.0. Average score (-3.3333333333333335)
# Win/lose count 13.5/10.0. Average score (-3.06)
# Win/lose count 9.5/6.0. Average score (-2.8076923076923075)
# Win/lose count 8.5/9.0. Average score (-2.7222222222222223)
# Win/lose count 9.5/12.0. Average score (-2.7142857142857144)
# Win/lose count 8.5/17.0. Average score (-2.913793103448276)
# Win/lose count 8.5/13.0. Average score (-2.966666666666667)
# Win/lose count 7.5/10.0. Average score (-2.9516129032258065)
# Win/lose count 5.5/12.0. Average score (-3.0625)
# Win/lose count 6.5/11.0. Average score (-3.106060606060606)
# Win/lose count 9.5/14.0. Average score (-3.1470588235294117)
# Win/lose count 13.0/8.0. Average score (-2.914285714285714)
# Win/lose count 11.0/21.0. Average score (-3.111111111111111)
# Win/lose count 9.5/21.0. Average score (-3.3378378378378377)
# Win/lose count 15.0/16.0. Average score (-3.276315789473684)
# Win/lose count 8.5/16.0. Average score (-3.3846153846153846)
# Win/lose count 8.5/17.0. Average score (-3.5125)
# Win/lose count 8.0/10.0. Average score (-3.475609756097561)
# Win/lose count 8.5/14.0. Average score (-3.5238095238095237)
# Win/lose count 7.0/10.0. Average score (-3.511627906976744)
# Win/lose count 14.5/13.0. Average score (-3.397727272727273)
# Win/lose count 9.5/10.0. Average score (-3.3333333333333335)
# Win/lose count 11.5/17.0. Average score (-3.380434782608696)
# Win/lose count 10.5/16.0. Average score (-3.425531914893617)
# Win/lose count 12.5/16.0. Average score (-3.4270833333333335)
# Win/lose count 9.0/21.0. Average score (-3.6020408163265305)
# Win/lose count 9.5/13.0. Average score (-3.6)
# Final score: -3.6
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# Let us assume here that $T=\infty$.
#
# ***
# __Question 5__ Let $\pi$ be a policy, show that:
#
# \begin{equation*}
# Q^{\pi}(s,a)=E_{(s',a')\sim p(.|s,a)}[r(s,a)+\gamma Q^{\pi}(s',a')]
# \end{equation*}
#
# Then, show that for the optimal policy $\pi^*$ (we assume its existence), the following holds:
#
# \begin{equation*}
# Q^{*}(s,a)=E_{s'\sim \pi^*(.|s,a)}[r(s,a)+\gamma\max_{a'}Q^{*}(s',a')].
# \end{equation*}
# Finally, deduce that a plausible objective is:
#
# \begin{equation*}
# \mathcal{L}(\theta)=E_{s' \sim \pi^*(.|s,a)}\Vert r+\gamma\max\max_{a'}Q(s',a',\theta)-Q(s,a,\theta)\Vert^{2}.
# \end{equation*}

# %% [markdown]
# $$
# \begin{align*}
# Q^\pi(s,a)=E_{p^{\pi}}[\sum_{t=0}^{\infty}\gamma^{t}r(s_{t},a_{t})|s_{0}=s,a_{0}=a]\\
#           =E_{p^{\pi}}[r(s_0,a_0) + \gamma\sum_{t=1}^{\infty}\gamma^{t-1}r(s_{t},a_{t})|s_{0}=s,a_{0}=a]\\
#           =r(s,a) + \gamma E_{p^{\pi}}[\sum_{t=0}^{\infty}\gamma^{t}r(s_{t+1},a_{t+1})|s_{0}=s,a_{0}=a]\\
#           =r(s,a) + \gamma E_{(s',a')\sim p(.|s,a)}\left(E_{p^{\pi}}[\sum_{t=0}^{\infty}\gamma^{t}r(s_{t},a_{t})|s_{0}=s',a_{0}=a']\right)\\
#           =E_{(s',a')\sim p(.|s,a)}\left(r(s,a) + \gamma E_{p^{\pi}}[\sum_{t=0}^{\infty}\gamma^{t}r(s_{t},a_{t})|s_{0}=s',a_{0}=a']\right)\\
#           =E_{(s',a')\sim p(.|s,a)}\left(r(s,a) + \gamma Q^{\pi}(s',a') \right)
# \end{align*}
# $$

# %% [markdown]
# $$
# \begin{align*}
# Q^*(s,a)
# Q^*(s,a) = \underset{(a',\pi')}{\max}\left[E_{(s',a')\sim p(.|s,a)}\left(r(s,a)+\gamma Q^{(a',\pi')}(s',a')\right)\right]\\
#  = \underset{(a',\pi')}{\max}\left[r(s,a) + \gamma \sum(p(s_{t+1}=s' |s_t = s, a_t = a )Q^{(a',\pi')}(s',a')\right]\\
# = r(s,a) + \gamma * \underset{(a',\pi')}{\max}\left[ \sum(p(s_{t+1}=s' |s_t = s, a_t = a )Q^{(a',\pi')}(s',a')\right]\\
# \end{align*}
# $$

# %% [markdown]
# We have seen previously that $Q^*$ is the solution of $F(Q) = 0$ with $$F(Q) = E_{s' \sim \pi^*(.|s,a)}\left(r(s,a) + \gamma \max_{a'}Q(s',a') - Q(s,a)\right)$$
#
# Hence, minimizing $\mathcal{L}(\theta)=E_{s' \sim \pi^*(.|s,a)}\Vert r(s,a) +\gamma\max_{a'}Q(s',a',\theta)-Q(s,a,\theta)\Vert^{2}$ will give the optimal policy.

# %% [markdown]
# ***
# The DQN-learning algorithm relies on these derivations to train the parameters $\theta$ of a Deep Neural Network:
#
# 1. At the state $s_t$, select the action $a_t$ with best reward using $Q_t$ and store the results;
#
# 2. Obtain the new state $s_{t+1}$ from the environment $p$;
#
# 3. Store $(s_t,a_t,s_{t+1})$;
#
# 4. Obtain $Q_{t+1}$ by minimizing  $\mathcal{L}$ from a recovered batch from the previously stored results.
#
# ***
# __Question 6__ Implement the class ```Memory``` that stores moves (in a replay buffer) via ```remember``` and provides a ```random_access``` to these. Specify a maximum memory size to avoid side effects. You can for example use a ```list()``` and set by default ```max_memory=100```.

# %%
class Memory(object):
    def __init__(self, max_memory=100):
        self.max_memory = max_memory
        self.memory = list()

    def remember(self, m):
        self.memory.append(m)
        if len(self.memory) > self.max_memory:
            del self.memory[0]

    def random_access(self):
        return self.memory[np.random.choice(len(self.memory))]

# %% [markdown]
# ***
# The pipeline we will use for training is given below:

# %%
def train(agent,env,epoch,prefix=''):
    # Number of won games
    score = 0
    loss = 0

    for e in range(epoch):
        # At each epoch, we restart to a fresh game and get the initial state
        state = env.reset()
        # This assumes that the games will terminate
        game_over = False

        win = 0
        lose = 0

        while not game_over:
            # The agent performs an action
            action = agent.act(state)

            # Apply an action to the environment, get the next state, the reward
            # and if the games end
            prev_state = state
            state, reward, game_over = env.act(action)

            # Update the counters
            if reward > 0:
                win = win + reward
            if reward < 0:
                lose = lose -reward

            # Apply the reinforcement strategy
            loss = agent.reinforce(prev_state, state,  action, reward, game_over)

        # Save as a mp4
        if e % 10 == 0:
            env.draw(prefix+str(e))

        # Update stats
        score += win-lose

        print("Epoch {:03d}/{:03d} | Loss {:.4f} | Win/lose count {}/{} ({})"
              .format(e, epoch, loss, win, lose, win-lose))
        agent.save(name_weights=prefix+'model.h5',name_model=prefix+'model.json')

# %% [markdown]
# ***
# __Question 7__ Implement the DQN training algorithm using a cascade of fully connected layers. You can use different learning rate, batch size or memory size parameters. In particular, the loss might oscillate while the player will start to win the games. You have to find a good criterium.

# %%
class DQN(Agent):
    def __init__(self, grid_size,  epsilon = 0.1, memory_size=100, batch_size = 16,n_state=2):
        super(DQN, self).__init__(epsilon = epsilon)

        # Discount for Q learning
        self.discount = 0.99
        
        self.grid_size = grid_size
        
        # number of state
        self.n_state = n_state

        # Memory
        self.memory = Memory(memory_size)
        
        # Batch size when learning
        self.batch_size = batch_size

    def learned_act(self, s):
        return np.argmax(self.model.predict(s.reshape((1,5,5,self.n_state))))

    def reinforce(self, s_, n_s_, a_, r_, game_over_):
        
        # Two steps: first memorize the states, second learn from the pool

        self.memory.remember([s_, n_s_, a_, r_, game_over_])
        
        input_states = np.zeros((self.batch_size, 5,5,self.n_state))
        target_q = np.zeros((self.batch_size, 4))
        
        for i in range(self.batch_size):
            st, nx_st, act, rw, g_o = self.memory.random_access()
            input_states[i] = st
            target_q[i] = self.model.predict([[st]])
            
            if game_over_:
                target_q[i][act] = rw
           
            else:
                p = self.model.predict([[nx_st]])
                mx_q = np.max(p)
                target_q[i][act] = rw + self.discount*mx_q
      
        # HINT: Clip the target to avoid exploiding gradients.. -- clipping is a bit tighter
        
        target_q = np.clip(target_q, -3, 3)

        l = self.model.train_on_batch(input_states, target_q)

        return l

    def save(self,name_weights = 'model.h5',name_model = 'model.json'):
        self.model.save_weights(name_weights, overwrite = True)
        with open(name_model, "w") as outfile:
            json.dump(self.model.to_json(), outfile)
            
    def load(self,name_weights = 'model.h5',name_model='model.json'):
        with open(name_model, "r") as jfile:
            model = model_from_json(json.load(jfile))
        model.load_weights(name_weights)
        model.compile("sgd", "mse")
        self.model = model

            
class DQN_FC(DQN):
    def __init__(self, *args, lr = 0.1,**kwargs):
        super(DQN_FC, self).__init__( *args,**kwargs)
        
        # NN Model
        
        model = Sequential()
        model.add(Flatten(input_shape = (5,5,self.n_state)))
        model.add(Dense(24, activation = 'relu'))
        model.add(Dense(24, activation = 'relu'))
        model.add(Dense(4, activation = 'linear'))
        model.compile(loss = 'mse', optimizer = Adam(lr = lr))
        
        model.compile(sgd(lr = lr, decay = 1e-4, momentum = 0.0), "mse")
        self.model = model

# %%
env = Environment(grid_size=size, max_time=T, temperature=0.3)
agent = DQN_FC(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
train(agent, env, epochs_train, prefix='fc_train')
HTML(display_videos('fc_train10.mp4'))
# Out:
# Epoch 000/100 | Loss 0.0472 | Win/lose count 4.0/5.0 (-1.0)
# Epoch 001/100 | Loss 0.0769 | Win/lose count 11.5/12.0 (-0.5)
# Epoch 002/100 | Loss 0.1852 | Win/lose count 3.0/1.0 (2.0)
# Epoch 003/100 | Loss 0.3900 | Win/lose count 6.0/5.0 (1.0)
# Epoch 004/100 | Loss 0.8750 | Win/lose count 4.5/8.0 (-3.5)
# Epoch 005/100 | Loss 1.3274 | Win/lose count 3.5/7.0 (-3.5)
# Epoch 006/100 | Loss 1.3702 | Win/lose count 5.0/2.0 (3.0)
# Epoch 007/100 | Loss 1.5081 | Win/lose count 3.5/4.0 (-0.5)
# Epoch 008/100 | Loss 1.7715 | Win/lose count 6.5/5.0 (1.5)
# Epoch 009/100 | Loss 1.5550 | Win/lose count 2.0/7.0 (-5.0)
# Epoch 010/100 | Loss 1.3798 | Win/lose count 2.0/2.0 (0.0)
# Epoch 011/100 | Loss 1.4926 | Win/lose count 2.5/4.0 (-1.5)
# Epoch 012/100 | Loss 1.3727 | Win/lose count 4.0/5.0 (-1.0)
# Epoch 013/100 | Loss 1.3894 | Win/lose count 8.0/1.0 (7.0)
# Epoch 014/100 | Loss 1.3978 | Win/lose count 2.0/5.0 (-3.0)
# Epoch 015/100 | Loss 1.4585 | Win/lose count 5.0/0 (5.0)
# Epoch 016/100 | Loss 1.5914 | Win/lose count 8.5/2.0 (6.5)
# Epoch 017/100 | Loss 1.6874 | Win/lose count 3.0/2.0 (1.0)
# Epoch 018/100 | Loss 1.8098 | Win/lose count 3.5/5.0 (-1.5)
# Epoch 019/100 | Loss 1.7940 | Win/lose count 5.0/4.0 (1.0)
# Epoch 020/100 | Loss 1.7422 | Win/lose count 8.5/3.0 (5.5)
# Epoch 021/100 | Loss 1.8133 | Win/lose count 5.5/4.0 (1.5)
# Epoch 022/100 | Loss 1.6199 | Win/lose count 10.5/15.0 (-4.5)
# Epoch 023/100 | Loss 1.6527 | Win/lose count 3.5/3.0 (0.5)
# Epoch 024/100 | Loss 1.7382 | Win/lose count 6.0/4.0 (2.0)
# Epoch 025/100 | Loss 1.6468 | Win/lose count 7.0/2.0 (5.0)
# Epoch 026/100 | Loss 1.6971 | Win/lose count 4.0/3.0 (1.0)
# Epoch 027/100 | Loss 1.5166 | Win/lose count 1.0/4.0 (-3.0)
# Epoch 028/100 | Loss 1.5784 | Win/lose count 11.5/2.0 (9.5)
# Epoch 029/100 | Loss 1.5620 | Win/lose count 6.5/5.0 (1.5)
# Epoch 030/100 | Loss 1.5684 | Win/lose count 9.0/1.0 (8.0)
# Epoch 031/100 | Loss 1.4892 | Win/lose count 9.5/4.0 (5.5)
# Epoch 032/100 | Loss 1.6703 | Win/lose count 8.0/1.0 (7.0)
# Epoch 033/100 | Loss 1.6384 | Win/lose count 7.0/1.0 (6.0)
# Epoch 034/100 | Loss 1.6147 | Win/lose count 15.5/1.0 (14.5)
# Epoch 035/100 | Loss 1.5799 | Win/lose count 10.5/1.0 (9.5)
# Epoch 036/100 | Loss 1.7002 | Win/lose count 6.0/1.0 (5.0)
# Epoch 037/100 | Loss 1.6970 | Win/lose count 6.0/1.0 (5.0)
# Epoch 038/100 | Loss 1.6741 | Win/lose count 8.5/1.0 (7.5)
# Epoch 039/100 | Loss 1.6999 | Win/lose count 12.0/1.0 (11.0)
# Epoch 040/100 | Loss 1.6779 | Win/lose count 8.5/2.0 (6.5)
# Epoch 041/100 | Loss 1.8344 | Win/lose count 4.0/3.0 (1.0)
# Epoch 042/100 | Loss 1.8528 | Win/lose count 7.5/4.0 (3.5)
# Epoch 043/100 | Loss 1.8000 | Win/lose count 6.5/4.0 (2.5)
# Epoch 044/100 | Loss 1.7090 | Win/lose count 17.0/1.0 (16.0)
# Epoch 045/100 | Loss 1.7291 | Win/lose count 11.5/3.0 (8.5)
# Epoch 046/100 | Loss 1.7821 | Win/lose count 14.5/3.0 (11.5)
# Epoch 047/100 | Loss 1.7224 | Win/lose count 3.5/0 (3.5)
# Epoch 048/100 | Loss 1.7821 | Win/lose count 7.5/1.0 (6.5)
# Epoch 049/100 | Loss 1.8010 | Win/lose count 12.0/0 (12.0)
# Epoch 050/100 | Loss 1.8324 | Win/lose count 7.0/2.0 (5.0)
# Epoch 051/100 | Loss 1.8200 | Win/lose count 12.5/5.0 (7.5)
# Epoch 052/100 | Loss 1.7795 | Win/lose count 5.0/3.0 (2.0)
# Epoch 053/100 | Loss 1.8245 | Win/lose count 10.5/4.0 (6.5)
# Epoch 054/100 | Loss 1.7879 | Win/lose count 15.5/5.0 (10.5)
# Epoch 055/100 | Loss 1.7783 | Win/lose count 10.0/2.0 (8.0)
# Epoch 056/100 | Loss 1.8210 | Win/lose count 9.5/3.0 (6.5)
# Epoch 057/100 | Loss 1.7099 | Win/lose count 7.5/1.0 (6.5)
# Epoch 058/100 | Loss 1.7723 | Win/lose count 2.5/0 (2.5)
# Epoch 059/100 | Loss 1.7044 | Win/lose count 18.5/3.0 (15.5)
# Epoch 060/100 | Loss 1.7194 | Win/lose count 5.5/1.0 (4.5)
# Epoch 061/100 | Loss 1.8291 | Win/lose count 11.0/3.0 (8.0)
# Epoch 062/100 | Loss 1.7520 | Win/lose count 6.5/1.0 (5.5)
# Epoch 063/100 | Loss 1.7783 | Win/lose count 4.5/2.0 (2.5)
# Epoch 064/100 | Loss 1.7697 | Win/lose count 4.5/2.0 (2.5)
# Epoch 065/100 | Loss 1.6612 | Win/lose count 10.5/3.0 (7.5)
# Epoch 066/100 | Loss 1.7270 | Win/lose count 6.0/0 (6.0)
# Epoch 067/100 | Loss 1.8040 | Win/lose count 11.5/2.0 (9.5)
# Epoch 068/100 | Loss 1.7452 | Win/lose count 7.0/2.0 (5.0)
# Epoch 069/100 | Loss 1.7633 | Win/lose count 3.5/2.0 (1.5)
# Epoch 070/100 | Loss 1.7351 | Win/lose count 3.5/1.0 (2.5)
# Epoch 071/100 | Loss 1.6811 | Win/lose count 9.0/1.0 (8.0)
# Epoch 072/100 | Loss 1.7727 | Win/lose count 13.5/4.0 (9.5)
# Epoch 073/100 | Loss 1.6722 | Win/lose count 3.5/1.0 (2.5)
# Epoch 074/100 | Loss 1.6763 | Win/lose count 6.5/1.0 (5.5)
# Epoch 075/100 | Loss 1.7542 | Win/lose count 6.0/1.0 (5.0)
# Epoch 076/100 | Loss 1.6278 | Win/lose count 6.0/0 (6.0)
# Epoch 077/100 | Loss 1.7273 | Win/lose count 9.5/1.0 (8.5)
# Epoch 078/100 | Loss 1.6940 | Win/lose count 9.0/2.0 (7.0)
# Epoch 079/100 | Loss 1.6496 | Win/lose count 7.0/3.0 (4.0)
# Epoch 080/100 | Loss 1.6645 | Win/lose count 7.5/2.0 (5.5)
# Epoch 081/100 | Loss 1.6471 | Win/lose count 5.5/0 (5.5)
# Epoch 082/100 | Loss 1.6255 | Win/lose count 10.5/1.0 (9.5)
# Epoch 083/100 | Loss 1.6253 | Win/lose count 5.5/2.0 (3.5)
# Epoch 084/100 | Loss 1.6972 | Win/lose count 13.0/2.0 (11.0)
# Epoch 085/100 | Loss 1.7081 | Win/lose count 13.0/2.0 (11.0)
# Epoch 086/100 | Loss 1.6461 | Win/lose count 14.5/2.0 (12.5)
# Epoch 087/100 | Loss 1.6830 | Win/lose count 6.5/2.0 (4.5)
# Epoch 088/100 | Loss 1.6360 | Win/lose count 9.5/1.0 (8.5)
# Epoch 089/100 | Loss 1.6635 | Win/lose count 20.0/0 (20.0)
# Epoch 090/100 | Loss 1.6860 | Win/lose count 11.0/1.0 (10.0)
# Epoch 091/100 | Loss 1.7156 | Win/lose count 16.0/2.0 (14.0)
# Epoch 092/100 | Loss 1.7145 | Win/lose count 7.5/2.0 (5.5)
# Epoch 093/100 | Loss 1.6252 | Win/lose count 13.5/1.0 (12.5)
# Epoch 094/100 | Loss 1.7133 | Win/lose count 15.0/0 (15.0)
# Epoch 095/100 | Loss 1.7261 | Win/lose count 14.5/2.0 (12.5)
# Epoch 096/100 | Loss 1.6880 | Win/lose count 9.5/5.0 (4.5)
# Epoch 097/100 | Loss 1.7479 | Win/lose count 16.0/5.0 (11.0)
# Epoch 098/100 | Loss 1.7752 | Win/lose count 3.0/1.0 (2.0)
# Epoch 099/100 | Loss 1.6673 | Win/lose count 9.5/2.0 (7.5)
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ***
# ***
# __Question 8__ Implement the DQN training algorithm using a CNN (for example, 2 convolutional layers and one final fully connected layer).

# %%
class DQN_CNN(DQN):
    def __init__(self, *args,lr=0.1,**kwargs):
        super(DQN_CNN, self).__init__(*args,**kwargs)
         
        model = Sequential()
        model.add(Conv2D(64, kernel_size = (3, 3), activation = 'relu', input_shape = (5,5,self.n_state)))
        model.add(Dropout(rate = 0.1))
        model.add(Conv2D(32, (3, 3), activation = 'relu'))
        model.add(Flatten())
        model.add(Dense(32))
        model.add(Dropout(rate = 0.1))
        model.add(Dense(4))
        
        model.compile(sgd(lr = lr, decay = 1e-4, momentum = 0.0), "mse")
        self.model = model

# %%
env = Environment(grid_size=size, max_time=T, temperature=0.3)
agent = DQN_CNN(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
train(agent,env,epochs_train,prefix='cnn_train')
HTML(display_videos('cnn_train10.mp4'))
# Out:
# Epoch 000/100 | Loss 0.0241 | Win/lose count 3.0/3.0 (0.0)
# Epoch 001/100 | Loss 0.0113 | Win/lose count 1.0/6.0 (-5.0)
# Epoch 002/100 | Loss 0.0249 | Win/lose count 8.0/4.0 (4.0)
# Epoch 003/100 | Loss 0.0341 | Win/lose count 3.0/4.0 (-1.0)
# Epoch 004/100 | Loss 0.0587 | Win/lose count 2.5/4.0 (-1.5)
# Epoch 005/100 | Loss 0.0597 | Win/lose count 6.0/1.0 (5.0)
# Epoch 006/100 | Loss 0.1169 | Win/lose count 3.5/3.0 (0.5)
# Epoch 007/100 | Loss 0.1273 | Win/lose count 2.5/2.0 (0.5)
# Epoch 008/100 | Loss 0.1620 | Win/lose count 1.0/2.0 (-1.0)
# Epoch 009/100 | Loss 0.1478 | Win/lose count 5.0/3.0 (2.0)
# Epoch 010/100 | Loss 0.1408 | Win/lose count 4.5/0 (4.5)
# Epoch 011/100 | Loss 0.1705 | Win/lose count 3.0/1.0 (2.0)
# Epoch 012/100 | Loss 0.1581 | Win/lose count 6.5/3.0 (3.5)
# Epoch 013/100 | Loss 0.1491 | Win/lose count 3.0/0 (3.0)
# Epoch 014/100 | Loss 0.1313 | Win/lose count 4.5/0 (4.5)
# Epoch 015/100 | Loss 0.1118 | Win/lose count 3.5/1.0 (2.5)
# Epoch 016/100 | Loss 0.1098 | Win/lose count 1.5/0 (1.5)
# Epoch 017/100 | Loss 0.1236 | Win/lose count 8.0/1.0 (7.0)
# Epoch 018/100 | Loss 0.1388 | Win/lose count 3.5/3.0 (0.5)
# Epoch 019/100 | Loss 0.1667 | Win/lose count 1.0/0 (1.0)
# Epoch 020/100 | Loss 0.1253 | Win/lose count 4.0/3.0 (1.0)
# Epoch 021/100 | Loss 0.1614 | Win/lose count 3.0/1.0 (2.0)
# Epoch 022/100 | Loss 0.2172 | Win/lose count 8.0/3.0 (5.0)
# Epoch 023/100 | Loss 0.2124 | Win/lose count 3.0/2.0 (1.0)
# Epoch 024/100 | Loss 0.1899 | Win/lose count 6.5/9.0 (-2.5)
# Epoch 025/100 | Loss 0.2025 | Win/lose count 5.5/9.0 (-3.5)
# Epoch 026/100 | Loss 0.1433 | Win/lose count 4.5/6.0 (-1.5)
# Epoch 027/100 | Loss 0.1068 | Win/lose count 3.0/4.0 (-1.0)
# Epoch 028/100 | Loss 0.1175 | Win/lose count 7.0/6.0 (1.0)
# Epoch 029/100 | Loss 0.1393 | Win/lose count 5.0/7.0 (-2.0)
# Epoch 030/100 | Loss 0.1699 | Win/lose count 8.0/5.0 (3.0)
# Epoch 031/100 | Loss 0.1838 | Win/lose count 6.5/2.0 (4.5)
# Epoch 032/100 | Loss 0.1674 | Win/lose count 4.0/2.0 (2.0)
# Epoch 033/100 | Loss 0.1737 | Win/lose count 3.0/1.0 (2.0)
# Epoch 034/100 | Loss 0.1816 | Win/lose count 10.0/4.0 (6.0)
# Epoch 035/100 | Loss 0.1971 | Win/lose count 7.5/6.0 (1.5)
# Epoch 036/100 | Loss 0.2080 | Win/lose count 7.5/2.0 (5.5)
# Epoch 037/100 | Loss 0.2044 | Win/lose count 8.0/7.0 (1.0)
# Epoch 038/100 | Loss 0.1821 | Win/lose count 4.5/4.0 (0.5)
# Epoch 039/100 | Loss 0.2274 | Win/lose count 8.5/5.0 (3.5)
# Epoch 040/100 | Loss 0.2236 | Win/lose count 10.5/6.0 (4.5)
# Epoch 041/100 | Loss 0.2284 | Win/lose count 7.5/4.0 (3.5)
# Epoch 042/100 | Loss 0.3356 | Win/lose count 12.5/6.0 (6.5)
# Epoch 043/100 | Loss 0.3193 | Win/lose count 12.0/2.0 (10.0)
# Epoch 044/100 | Loss 0.3217 | Win/lose count 7.5/3.0 (4.5)
# Epoch 045/100 | Loss 0.3629 | Win/lose count 6.5/5.0 (1.5)
# Epoch 046/100 | Loss 0.3875 | Win/lose count 16.5/4.0 (12.5)
# Epoch 047/100 | Loss 0.4704 | Win/lose count 13.5/2.0 (11.5)
# Epoch 048/100 | Loss 0.4961 | Win/lose count 15.5/1.0 (14.5)
# Epoch 049/100 | Loss 0.6109 | Win/lose count 10.0/4.0 (6.0)
# Epoch 050/100 | Loss 0.7718 | Win/lose count 11.0/7.0 (4.0)
# Epoch 051/100 | Loss 0.8261 | Win/lose count 12.5/9.0 (3.5)
# Epoch 052/100 | Loss 0.9062 | Win/lose count 11.0/7.0 (4.0)
# Epoch 053/100 | Loss 0.8413 | Win/lose count 7.5/4.0 (3.5)
# Epoch 054/100 | Loss 0.8643 | Win/lose count 23.5/6.0 (17.5)
# Epoch 055/100 | Loss 0.9857 | Win/lose count 18.0/7.0 (11.0)
# Epoch 056/100 | Loss 0.9803 | Win/lose count 20.5/5.0 (15.5)
# Epoch 057/100 | Loss 1.0343 | Win/lose count 17.0/5.0 (12.0)
# Epoch 058/100 | Loss 1.1503 | Win/lose count 17.5/6.0 (11.5)
# Epoch 059/100 | Loss 1.2093 | Win/lose count 23.0/4.0 (19.0)
# Epoch 060/100 | Loss 1.1557 | Win/lose count 13.0/4.0 (9.0)
# Epoch 061/100 | Loss 1.2304 | Win/lose count 10.5/4.0 (6.5)
# Epoch 062/100 | Loss 1.2936 | Win/lose count 15.0/2.0 (13.0)
# Epoch 063/100 | Loss 1.2082 | Win/lose count 15.0/4.0 (11.0)
# Epoch 064/100 | Loss 1.2665 | Win/lose count 15.0/4.0 (11.0)
# Epoch 065/100 | Loss 1.2346 | Win/lose count 18.0/0 (18.0)
# Epoch 066/100 | Loss 1.3299 | Win/lose count 17.0/4.0 (13.0)
# Epoch 067/100 | Loss 1.4056 | Win/lose count 15.5/3.0 (12.5)
# Epoch 068/100 | Loss 1.4153 | Win/lose count 7.5/1.0 (6.5)
# Epoch 069/100 | Loss 1.2041 | Win/lose count 12.5/4.0 (8.5)
# Epoch 070/100 | Loss 1.2715 | Win/lose count 20.5/3.0 (17.5)
# Epoch 071/100 | Loss 1.3962 | Win/lose count 24.5/5.0 (19.5)
# Epoch 072/100 | Loss 1.4228 | Win/lose count 24.5/5.0 (19.5)
# Epoch 073/100 | Loss 1.3646 | Win/lose count 16.5/4.0 (12.5)
# Epoch 074/100 | Loss 1.3204 | Win/lose count 20.5/4.0 (16.5)
# Epoch 075/100 | Loss 1.2797 | Win/lose count 6.5/1.0 (5.5)
# Epoch 076/100 | Loss 1.4097 | Win/lose count 20.5/3.0 (17.5)
# Epoch 077/100 | Loss 1.4184 | Win/lose count 15.5/2.0 (13.5)
# Epoch 078/100 | Loss 1.4608 | Win/lose count 9.0/3.0 (6.0)
# Epoch 079/100 | Loss 1.4747 | Win/lose count 12.5/3.0 (9.5)
# Epoch 080/100 | Loss 1.3854 | Win/lose count 25.5/4.0 (21.5)
# Epoch 081/100 | Loss 1.4493 | Win/lose count 16.5/0 (16.5)
# Epoch 082/100 | Loss 1.5837 | Win/lose count 19.5/3.0 (16.5)
# Epoch 083/100 | Loss 1.5126 | Win/lose count 17.5/4.0 (13.5)
# Epoch 084/100 | Loss 1.4373 | Win/lose count 15.5/2.0 (13.5)
# Epoch 085/100 | Loss 1.4129 | Win/lose count 13.0/2.0 (11.0)
# Epoch 086/100 | Loss 1.5012 | Win/lose count 18.5/1.0 (17.5)
# Epoch 087/100 | Loss 1.5248 | Win/lose count 14.0/2.0 (12.0)
# Epoch 088/100 | Loss 1.4331 | Win/lose count 16.0/2.0 (14.0)
# Epoch 089/100 | Loss 1.4400 | Win/lose count 24.0/4.0 (20.0)
# Epoch 090/100 | Loss 1.4826 | Win/lose count 26.5/3.0 (23.5)
# Epoch 091/100 | Loss 1.5291 | Win/lose count 17.5/2.0 (15.5)
# Epoch 092/100 | Loss 1.6258 | Win/lose count 19.5/7.0 (12.5)
# Epoch 093/100 | Loss 1.5713 | Win/lose count 21.5/2.0 (19.5)
# Epoch 094/100 | Loss 1.5844 | Win/lose count 22.0/2.0 (20.0)
# Epoch 095/100 | Loss 1.5353 | Win/lose count 11.0/0 (11.0)
# Epoch 096/100 | Loss 1.5532 | Win/lose count 17.0/3.0 (14.0)
# Epoch 097/100 | Loss 1.6380 | Win/lose count 14.0/0 (14.0)
# Epoch 098/100 | Loss 1.5892 | Win/lose count 23.0/9.0 (14.0)
# Epoch 099/100 | Loss 1.4842 | Win/lose count 12.0/2.0 (10.0)
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ***
# ***
# __Question 9__ Test both algorithms and compare their performances. Which issue(s) do you observe? Observe also different behaviors by changing the temperature.

# %%
env = Environment(grid_size=size, max_time=T,temperature=0.3)
agent_cnn = DQN_CNN(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
agent_cnn.load(name_weights='cnn_trainmodel.h5',name_model='cnn_trainmodel.json')

agent_fc = DQN_FC(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
agent_cnn.load(name_weights='fc_trainmodel.h5',name_model='fc_trainmodel.json')
print('Test of the CNN')
test(agent_cnn,env,epochs_test,prefix='cnn_test')
print('Test of the FC')
test(agent_fc,env,epochs_test,prefix='fc_test')
# Out:
# Test of the CNN
# Win/lose count 5.5/2.0. Average score (3.5)
# Win/lose count 4.5/1.0. Average score (3.5)
# Win/lose count 6.5/1.0. Average score (4.166666666666667)
# Win/lose count 6.5/2.0. Average score (4.25)
# Win/lose count 6.5/3.0. Average score (4.1)
# Win/lose count 1.5/0. Average score (3.6666666666666665)
# Win/lose count 9.0/2.0. Average score (4.142857142857143)
# Win/lose count 12.5/5.0. Average score (4.5625)
# Win/lose count 9.5/4.0. Average score (4.666666666666667)
# Win/lose count 2.5/2.0. Average score (4.25)
# Win/lose count 9.5/2.0. Average score (4.545454545454546)
# Win/lose count 6.0/4.0. Average score (4.333333333333333)
# Win/lose count 7.0/0. Average score (4.538461538461538)
# Win/lose count 7.5/1.0. Average score (4.678571428571429)
# Win/lose count 5.5/3.0. Average score (4.533333333333333)
# Win/lose count 3.5/1.0. Average score (4.40625)
# Win/lose count 6.0/4.0. Average score (4.264705882352941)
# Win/lose count 2.0/1.0. Average score (4.083333333333333)
# Win/lose count 15.0/3.0. Average score (4.5)
# Win/lose count 13.0/2.0. Average score (4.825)
# Win/lose count 6.0/0. Average score (4.880952380952381)
# Win/lose count 9.0/2.0. Average score (4.9772727272727275)
# Win/lose count 10.5/4.0. Average score (5.043478260869565)
# Win/lose count 10.0/0. Average score (5.25)
# Win/lose count 17.0/2.0. Average score (5.64)
# Win/lose count 10.0/0. Average score (5.8076923076923075)
# Win/lose count 11.5/3.0. Average score (5.907407407407407)
# Win/lose count 8.0/2.0. Average score (5.910714285714286)
# Win/lose count 3.5/0. Average score (5.827586206896552)
# Win/lose count 11.0/2.0. Average score (5.933333333333334)
# Win/lose count 5.5/1.0. Average score (5.887096774193548)
# Win/lose count 4.0/2.0. Average score (5.765625)
# Win/lose count 10.5/2.0. Average score (5.848484848484849)
# Win/lose count 18.0/3.0. Average score (6.117647058823529)
# Win/lose count 6.0/1.0. Average score (6.085714285714285)
# Win/lose count 9.5/3.0. Average score (6.097222222222222)
# Win/lose count 4.5/1.0. Average score (6.027027027027027)
# Win/lose count 10.0/4.0. Average score (6.026315789473684)
# Win/lose count 10.5/5.0. Average score (6.012820512820513)
# Win/lose count 7.0/1.0. Average score (6.0125)
# Win/lose count 10.5/1.0. Average score (6.097560975609756)
# Win/lose count 8.0/2.0. Average score (6.095238095238095)
# Win/lose count 2.0/1.0. Average score (5.976744186046512)
# Win/lose count 9.5/0. Average score (6.056818181818182)
# Win/lose count 7.0/2.0. Average score (6.033333333333333)
# Win/lose count 8.5/4.0. Average score (6.0)
# Win/lose count 3.0/1.0. Average score (5.914893617021277)
# Win/lose count 9.0/1.0. Average score (5.958333333333333)
# Win/lose count 4.5/3.0. Average score (5.86734693877551)
# Win/lose count 9.5/1.0. Average score (5.92)
# Final score: 5.92
# Test of the FC
# Win/lose count 3.0/6.0. Average score (-3.0)
# Win/lose count 3.0/7.0. Average score (-3.5)
# Win/lose count 3.5/6.0. Average score (-3.1666666666666665)
# Win/lose count 2.0/11.0. Average score (-4.625)
# Win/lose count 6.0/7.0. Average score (-3.9)
# Win/lose count 2.0/1.0. Average score (-3.0833333333333335)
# Win/lose count 4.5/6.0. Average score (-2.857142857142857)
# Win/lose count 2.5/7.0. Average score (-3.0625)
# Win/lose count 1.5/5.0. Average score (-3.111111111111111)
# Win/lose count 4.0/5.0. Average score (-2.9)
# Win/lose count 1.5/5.0. Average score (-2.9545454545454546)
# Win/lose count 4.0/3.0. Average score (-2.625)
# Win/lose count 1.5/3.0. Average score (-2.5384615384615383)
# Win/lose count 3.0/2.0. Average score (-2.2857142857142856)
# Win/lose count 2.0/1.0. Average score (-2.066666666666667)
# Win/lose count 2.5/4.0. Average score (-2.03125)
# Win/lose count 5.5/6.0. Average score (-1.9411764705882353)
# Win/lose count 5.5/8.0. Average score (-1.9722222222222223)
# Win/lose count 3.0/4.0. Average score (-1.9210526315789473)
# Win/lose count 4.5/6.0. Average score (-1.9)
# Win/lose count 2.0/4.0. Average score (-1.9047619047619047)
# Win/lose count 0.5/3.0. Average score (-1.9318181818181819)
# Win/lose count 3.5/5.0. Average score (-1.9130434782608696)
# Win/lose count 4.0/6.0. Average score (-1.9166666666666667)
# Win/lose count 5.5/6.0. Average score (-1.86)
# Win/lose count 3.5/4.0. Average score (-1.8076923076923077)
# Win/lose count 4.5/3.0. Average score (-1.6851851851851851)
# Win/lose count 2.0/6.0. Average score (-1.7678571428571428)
# Win/lose count 3.5/8.0. Average score (-1.8620689655172413)
# Win/lose count 1.5/5.0. Average score (-1.9166666666666667)
# Win/lose count 2.0/2.0. Average score (-1.8548387096774193)
# Win/lose count 3.5/7.0. Average score (-1.90625)
# Win/lose count 3.0/7.0. Average score (-1.9696969696969697)
# Win/lose count 3.0/4.0. Average score (-1.9411764705882353)
# Win/lose count 4.0/4.0. Average score (-1.8857142857142857)
# Win/lose count 1.5/1.0. Average score (-1.8194444444444444)
# Win/lose count 1.0/2.0. Average score (-1.7972972972972974)
# Win/lose count 2.0/6.0. Average score (-1.855263157894737)
# Win/lose count 3.0/3.0. Average score (-1.8076923076923077)
# Win/lose count 3.5/4.0. Average score (-1.775)
# Win/lose count 3.0/2.0. Average score (-1.7073170731707317)
# Win/lose count 3.5/5.0. Average score (-1.7023809523809523)
# Win/lose count 1.5/3.0. Average score (-1.697674418604651)
# Win/lose count 1.0/2.0. Average score (-1.6818181818181819)
# Win/lose count 3.0/2.0. Average score (-1.6222222222222222)
# Win/lose count 1.5/3.0. Average score (-1.6195652173913044)
# Win/lose count 0.5/3.0. Average score (-1.6382978723404256)
# Win/lose count 1.5/2.0. Average score (-1.6145833333333333)
# Win/lose count 1.0/1.0. Average score (-1.5816326530612246)
# Win/lose count 0.5/5.0. Average score (-1.64)
# Final score: -1.64

# %% [markdown]
# We can observe that the performances of the CNN are better than those of FC. We can also say that the agent is not exploring the map as it should (not exploring it all).

# %%
env = Environment(grid_size=size, max_time=T,temperature=0.8)
agent_cnn = DQN_CNN(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
agent_cnn.load(name_weights='cnn_trainmodel.h5',name_model='cnn_trainmodel.json')

agent_fc = DQN_FC(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
agent_cnn.load(name_weights='fc_trainmodel.h5',name_model='fc_trainmodel.json')
print('Test of the CNN')
test(agent_cnn,env,epochs_test,prefix='cnn_test')
print('Test of the FC')
test(agent_fc,env,epochs_test,prefix='fc_test')
# Out:
# Test of the CNN
# Win/lose count 18.5/2.0. Average score (16.5)
# Win/lose count 17.0/2.0. Average score (15.75)
# Win/lose count 23.0/1.0. Average score (17.833333333333332)
# Win/lose count 20.0/1.0. Average score (18.125)
# Win/lose count 28.0/2.0. Average score (19.7)
# Win/lose count 19.0/2.0. Average score (19.25)
# Win/lose count 22.5/0. Average score (19.714285714285715)
# Win/lose count 42.5/3.0. Average score (22.1875)
# Win/lose count 19.0/2.0. Average score (21.61111111111111)
# Win/lose count 19.0/3.0. Average score (21.05)
# Win/lose count 15.0/0. Average score (20.5)
# Win/lose count 25.0/3.0. Average score (20.625)
# Win/lose count 19.5/0. Average score (20.53846153846154)
# Win/lose count 41.0/1.0. Average score (21.928571428571427)
# Win/lose count 28.0/3.0. Average score (22.133333333333333)
# Win/lose count 8.5/0. Average score (21.28125)
# Win/lose count 15.5/0. Average score (20.941176470588236)
# Win/lose count 36.5/1.0. Average score (21.75)
# Win/lose count 9.0/1.0. Average score (21.026315789473685)
# Win/lose count 39.5/1.0. Average score (21.9)
# Win/lose count 11.5/1.0. Average score (21.357142857142858)
# Win/lose count 15.5/1.0. Average score (21.045454545454547)
# Win/lose count 21.0/1.0. Average score (21.0)
# Win/lose count 24.5/2.0. Average score (21.0625)
# Win/lose count 22.0/1.0. Average score (21.06)
# Win/lose count 26.0/1.0. Average score (21.21153846153846)
# Win/lose count 27.5/3.0. Average score (21.333333333333332)
# Win/lose count 23.5/1.0. Average score (21.375)
# Win/lose count 20.0/1.0. Average score (21.29310344827586)
# Win/lose count 16.0/1.0. Average score (21.083333333333332)
# Win/lose count 9.0/1.0. Average score (20.661290322580644)
# Win/lose count 21.5/4.0. Average score (20.5625)
# Win/lose count 17.5/0. Average score (20.46969696969697)
# Win/lose count 42.0/2.0. Average score (21.044117647058822)
# Win/lose count 18.5/0. Average score (20.97142857142857)
# Win/lose count 28.5/3.0. Average score (21.09722222222222)
# Win/lose count 38.0/1.0. Average score (21.527027027027028)
# Win/lose count 48.0/1.0. Average score (22.19736842105263)
# Win/lose count 19.0/1.0. Average score (22.08974358974359)
# Win/lose count 37.0/1.0. Average score (22.4375)
# Win/lose count 19.5/2.0. Average score (22.317073170731707)
# Win/lose count 13.0/6.0. Average score (21.952380952380953)
# Win/lose count 17.5/1.0. Average score (21.825581395348838)
# Win/lose count 18.0/3.0. Average score (21.670454545454547)
# Win/lose count 20.5/2.0. Average score (21.6)
# Win/lose count 27.5/0. Average score (21.72826086956522)
# Win/lose count 9.5/1.0. Average score (21.4468085106383)
# Win/lose count 46.5/2.0. Average score (21.927083333333332)
# Win/lose count 8.5/1.0. Average score (21.632653061224488)
# Win/lose count 25.0/1.0. Average score (21.68)
# Final score: 21.68
# Test of the FC
# Win/lose count 4.5/4.0. Average score (0.5)
# Win/lose count 8.5/4.0. Average score (2.5)
# Win/lose count 6.0/4.0. Average score (2.3333333333333335)
# Win/lose count 8.5/4.0. Average score (2.875)
# Win/lose count 4.0/1.0. Average score (2.9)
# Win/lose count 7.5/3.0. Average score (3.1666666666666665)
# Win/lose count 13.5/7.0. Average score (3.642857142857143)
# Win/lose count 12.5/2.0. Average score (4.5)
# Win/lose count 4.0/3.0. Average score (4.111111111111111)
# Win/lose count 6.5/2.0. Average score (4.15)
# Win/lose count 7.0/1.0. Average score (4.318181818181818)
# Win/lose count 3.5/1.0. Average score (4.166666666666667)
# Win/lose count 12.0/7.0. Average score (4.230769230769231)
# Win/lose count 11.5/11.0. Average score (3.9642857142857144)
# Win/lose count 8.5/4.0. Average score (4.0)
# Win/lose count 2.5/1.0. Average score (3.84375)
# Win/lose count 7.5/5.0. Average score (3.764705882352941)
# Win/lose count 4.0/1.0. Average score (3.7222222222222223)
# Win/lose count 13.5/10.0. Average score (3.710526315789474)
# Win/lose count 10.5/4.0. Average score (3.85)
# Win/lose count 11.0/4.0. Average score (4.0)
# Win/lose count 8.0/4.0. Average score (4.0)
# Win/lose count 7.0/7.0. Average score (3.8260869565217392)
# Win/lose count 11.5/5.0. Average score (3.9375)
# Win/lose count 6.5/2.0. Average score (3.96)
# Win/lose count 10.0/4.0. Average score (4.038461538461538)
# Win/lose count 7.0/3.0. Average score (4.037037037037037)
# Win/lose count 12.5/3.0. Average score (4.232142857142857)
# Win/lose count 9.5/2.0. Average score (4.344827586206897)
# Win/lose count 11.0/1.0. Average score (4.533333333333333)
# Win/lose count 8.0/4.0. Average score (4.516129032258065)
# Win/lose count 5.5/3.0. Average score (4.453125)
# Win/lose count 9.5/2.0. Average score (4.545454545454546)
# Win/lose count 4.0/0. Average score (4.529411764705882)
# Win/lose count 7.5/4.0. Average score (4.5)
# Win/lose count 6.5/1.0. Average score (4.527777777777778)
# Win/lose count 4.5/3.0. Average score (4.445945945945946)
# Win/lose count 11.5/6.0. Average score (4.473684210526316)
# Win/lose count 5.0/4.0. Average score (4.384615384615385)
# Win/lose count 5.0/5.0. Average score (4.275)
# Win/lose count 11.0/1.0. Average score (4.414634146341464)
# Win/lose count 1.5/2.0. Average score (4.2976190476190474)
# Win/lose count 9.0/4.0. Average score (4.313953488372093)
# Win/lose count 10.0/6.0. Average score (4.306818181818182)
# Win/lose count 10.5/3.0. Average score (4.377777777777778)
# Win/lose count 10.5/4.0. Average score (4.423913043478261)
# Win/lose count 5.5/0. Average score (4.446808510638298)
# Win/lose count 5.5/1.0. Average score (4.447916666666667)
# Win/lose count 8.5/4.0. Average score (4.448979591836735)
# Win/lose count 10.5/4.0. Average score (4.49)
# Final score: 4.49

# %% [markdown]
# When increasing the temperature, we observe an improvement in the map exploration.

# %%
HTML(display_videos('cnn_test10.mp4'))
# Out:
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
HTML(display_videos('fc_test10.mp4'))
# Out:
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ***
#
# The algorithm tends to not explore the map which can be an issue. We propose two ideas in order to encourage exploration:
# 1. Incorporating a decreasing $\epsilon$-greedy exploration. You can use the method ```set_epsilon```
# 2. Append via the environment a new state that describes if a cell has been visited or not
#
# ***
# __Question 10__ Design a new ```train_explore``` function and environment class ```EnvironmentExploring``` to tackle the issue of exploration.

# %%
def train_explore(agent,env,epoch,prefix=''):
    # Number of won games
    score = 0
    loss = 0
    
    agent.epsilon = 1.

    for e in range(epoch):
        # At each epoch, we restart to a fresh game and get the initial state
        state = env.reset()
        # This assumes that the games will terminate
        game_over = False

        win = 0
        lose = 0
        
        agent.epsilon = agent.epsilon * 0.95
        while not game_over:
            # The agent performs an action
            action = agent.act(state)

            # Apply an action to the environment, get the next state, the reward
            # and if the games end
            prev_state = state
            state, reward, game_over = env.act(action, train =True)

            # Update the counters
            if reward > 0:
                win = win + reward
            if reward < 0:
                lose = lose -reward

            # Apply the reinforcement strategy
            loss = agent.reinforce(prev_state, state,  action, reward, game_over)

        # Save as a mp4
        if e % 10 == 0:
            env.draw(prefix+str(e))

        # Update stats
        score += win-lose

        print("Epoch {:03d}/{:03d} | Loss {:.4f} | Win/lose count {}/{} ({})"
              .format(e, epoch, loss, win, lose, win-lose))
        agent.save(name_weights=prefix+'model.h5',name_model=prefix+'model.json')
   
    
        
class EnvironmentExploring(object):
    def __init__(self, grid_size=10, max_time=500, temperature=0.1):
        grid_size = grid_size+4
        self.grid_size = grid_size
        self.max_time = max_time
        self.temperature = temperature

        #board on which one plays
        self.board = np.zeros((grid_size,grid_size))
        self.position = np.zeros((grid_size,grid_size))
        self.malus_position = np.zeros((grid_size,grid_size))
        
        # coordinate of the cat
        self.x = 0
        self.y = 1

        # self time
        self.t = 0

        self.scale=16

        self.to_draw = np.zeros((max_time+2, grid_size*self.scale, grid_size*self.scale, 3))
        
    def draw(self,e):
        skvideo.io.vwrite(str(e) + '.mp4', self.to_draw)

    def get_frame(self,t):
        b = np.zeros((self.grid_size,self.grid_size,3))+128
        b[self.board>0,0] = 256
        b[self.board < 0, 2] = 256
        b[self.x,self.y,:]=256
        b[-2:,:,:]=0
        b[:,-2:,:]=0
        b[:2,:,:]=0
        b[:,:2,:]=0
        
        b =  cv2.resize(b, None, fx=self.scale, fy=self.scale, interpolation=cv2.INTER_NEAREST)

        self.to_draw[t,:,:,:]=b
        
    def act(self, action, train= False):
        """This function returns the new state, reward and decides if the
        game ends."""

        self.get_frame(int(self.t))

        self.position = np.zeros((self.grid_size, self.grid_size))

        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:, :] = -1
        self.position[:, :-2] = -1

        self.position[self.x, self.y] = 1
        if action == 0:
            if self.x == self.grid_size-3:
                self.x = self.x-1
            else:
                self.x = self.x + 1
        elif action == 1:
            if self.x == 2:
                self.x = self.x+1
            else:
                self.x = self.x-1
        elif action == 2:
            if self.y == self.grid_size - 3:
                self.y = self.y - 1
            else:
                self.y = self.y + 1
        elif action == 3:
            if self.y == 2:
                self.y = self.y + 1
            else:
                self.y = self.y - 1
        else:
            RuntimeError('Error: action not recognized')

        self.t = self.t + 1
        
        reward = 0
        if train:
            reward = -self.malus_position[self.x, self.y]
            self.malus_position[self.x, self.y] = 0.1
        reward = reward + self.board[self.x, self.y]
        
        self.board[self.x, self.y] = 0
        game_over = self.t > self.max_time
        state = np.concatenate((self.malus_position.reshape(self.grid_size, self.grid_size,1),
                        self.board.reshape(self.grid_size, self.grid_size,1),
                        self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)
        state = state[self.x-2:self.x+3,self.y-2:self.y+3,:]

        return state, reward, game_over

    def reset(self):
        """This function resets the game and returns the initial state"""

        self.x = np.random.randint(3, self.grid_size-3, size=1)[0]
        self.y = np.random.randint(3, self.grid_size-3, size=1)[0]


        bonus = 0.5*np.random.binomial(1,self.temperature,size=self.grid_size**2)
        bonus = bonus.reshape(self.grid_size,self.grid_size)

        malus = -1.0*np.random.binomial(1,self.temperature,size=self.grid_size**2)
        malus = malus.reshape(self.grid_size, self.grid_size)

        self.to_draw = np.zeros((self.max_time+2, self.grid_size*self.scale, self.grid_size*self.scale, 3))


        malus[bonus>0]=0

        self.board = bonus + malus

        self.position = np.zeros((self.grid_size, self.grid_size))
        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:, :] = -1
        self.position[-2:, :] = -1
        self.board[self.x,self.y] = 0
        self.t = 0
        
        self.malus_position = np.zeros((self.grid_size,self.grid_size))

        state = np.concatenate((self.malus_position.reshape(self.grid_size, self.grid_size,1),
                               self.board.reshape(self.grid_size, self.grid_size,1),
                        self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)

        state = state[self.x - 2:self.x + 3, self.y - 2:self.y + 3, :]
        return state

# %%
# Training
env = EnvironmentExploring(grid_size=size, max_time=T, temperature=0.3)
agent = DQN_CNN(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32,n_state=3)
train_explore(agent, env, epochs_train, prefix='cnn_train_explore')
HTML(display_videos('cnn_train_explore10.mp4'))
# Out:
# Epoch 000/100 | Loss 0.4176 | Win/lose count 14.0/24.100000000000065 (-10.100000000000065)
# Epoch 001/100 | Loss 0.1455 | Win/lose count 7.5/28.400000000000077 (-20.900000000000077)
# Epoch 002/100 | Loss 0.2125 | Win/lose count 6.5/24.300000000000068 (-17.800000000000068)
# Epoch 003/100 | Loss 0.2430 | Win/lose count 11.0/28.700000000000102 (-17.700000000000102)
# Epoch 004/100 | Loss 0.2418 | Win/lose count 10.0/29.000000000000068 (-19.000000000000068)
# Epoch 005/100 | Loss 0.3409 | Win/lose count 3.0/23.900000000000055 (-20.900000000000055)
# Epoch 006/100 | Loss 0.3075 | Win/lose count 7.0/20.70000000000003 (-13.700000000000031)
# Epoch 007/100 | Loss 0.4363 | Win/lose count 12.5/20.90000000000003 (-8.40000000000003)
# Epoch 008/100 | Loss 0.4730 | Win/lose count 12.5/23.800000000000043 (-11.300000000000043)
# Epoch 009/100 | Loss 0.9091 | Win/lose count 11.0/21.60000000000002 (-10.60000000000002)
# Epoch 010/100 | Loss 1.0479 | Win/lose count 17.5/23.100000000000065 (-5.600000000000065)
# Epoch 011/100 | Loss 0.8863 | Win/lose count 17.0/20.000000000000018 (-3.0000000000000178)
# Epoch 012/100 | Loss 1.5575 | Win/lose count 14.0/24.100000000000087 (-10.100000000000087)
# Epoch 013/100 | Loss 0.6938 | Win/lose count 13.5/19.900000000000034 (-6.400000000000034)
# Epoch 014/100 | Loss 1.3224 | Win/lose count 20.5/17.899999999999984 (2.6000000000000156)
# Epoch 015/100 | Loss 1.5238 | Win/lose count 14.5/17.19999999999998 (-2.6999999999999815)
# Epoch 016/100 | Loss 1.5571 | Win/lose count 18.0/17.799999999999983 (0.20000000000001705)
# Epoch 017/100 | Loss 1.2086 | Win/lose count 11.5/19.099999999999994 (-7.599999999999994)
# Epoch 018/100 | Loss 1.4391 | Win/lose count 19.5/20.70000000000003 (-1.2000000000000313)
# Epoch 019/100 | Loss 1.3358 | Win/lose count 8.5/19.100000000000005 (-10.600000000000005)
# Epoch 020/100 | Loss 1.2649 | Win/lose count 8.0/23.80000000000007 (-15.800000000000072)
# Epoch 021/100 | Loss 1.3023 | Win/lose count 19.5/16.899999999999988 (2.600000000000012)
# Epoch 022/100 | Loss 1.4832 | Win/lose count 16.5/18.300000000000004 (-1.8000000000000043)
# Epoch 023/100 | Loss 1.1722 | Win/lose count 14.5/19.800000000000015 (-5.300000000000015)
# Epoch 024/100 | Loss 1.2397 | Win/lose count 6.5/19.80000000000002 (-13.300000000000018)
# Epoch 025/100 | Loss 1.0648 | Win/lose count 17.0/21.30000000000004 (-4.30000000000004)
# Epoch 026/100 | Loss 1.2392 | Win/lose count 16.0/20.40000000000002 (-4.40000000000002)
# Epoch 027/100 | Loss 0.7781 | Win/lose count 19.5/20.29999999999999 (-0.79999999999999)
# Epoch 028/100 | Loss 0.9826 | Win/lose count 14.5/19.20000000000001 (-4.70000000000001)
# Epoch 029/100 | Loss 0.9800 | Win/lose count 25.0/17.699999999999992 (7.300000000000008)
# Epoch 030/100 | Loss 1.2586 | Win/lose count 25.0/17.499999999999975 (7.500000000000025)
# Epoch 031/100 | Loss 1.1706 | Win/lose count 10.5/16.899999999999974 (-6.399999999999974)
# Epoch 032/100 | Loss 1.1740 | Win/lose count 19.5/14.699999999999974 (4.800000000000026)
# Epoch 033/100 | Loss 1.1620 | Win/lose count 25.0/15.79999999999997 (9.20000000000003)
# Epoch 034/100 | Loss 1.2820 | Win/lose count 25.0/16.999999999999993 (8.000000000000007)
# Epoch 035/100 | Loss 1.2388 | Win/lose count 15.0/17.199999999999964 (-2.1999999999999638)
# Epoch 036/100 | Loss 1.4056 | Win/lose count 23.0/21.30000000000002 (1.6999999999999815)
# Epoch 037/100 | Loss 1.3005 | Win/lose count 20.5/17.799999999999994 (2.7000000000000064)
# Epoch 038/100 | Loss 1.1958 | Win/lose count 22.0/18.09999999999999 (3.9000000000000092)
# Epoch 039/100 | Loss 1.2172 | Win/lose count 18.0/14.79999999999997 (3.2000000000000295)
# Epoch 040/100 | Loss 1.2742 | Win/lose count 20.5/16.499999999999968 (4.000000000000032)
# Epoch 041/100 | Loss 1.0949 | Win/lose count 15.0/17.999999999999996 (-2.9999999999999964)
# Epoch 042/100 | Loss 1.1215 | Win/lose count 21.0/16.199999999999974 (4.800000000000026)
# Epoch 043/100 | Loss 1.2120 | Win/lose count 8.0/22.70000000000005 (-14.700000000000049)
# Epoch 044/100 | Loss 1.0782 | Win/lose count 15.0/15.499999999999963 (-0.4999999999999627)
# Epoch 045/100 | Loss 1.1810 | Win/lose count 19.0/13.399999999999972 (5.600000000000028)
# Epoch 046/100 | Loss 0.9543 | Win/lose count 14.5/15.599999999999964 (-1.0999999999999641)
# Epoch 047/100 | Loss 0.9429 | Win/lose count 13.5/16.69999999999997 (-3.199999999999971)
# Epoch 048/100 | Loss 0.9891 | Win/lose count 20.0/12.699999999999973 (7.300000000000027)
# Epoch 049/100 | Loss 0.8883 | Win/lose count 21.0/15.89999999999997 (5.10000000000003)
# Epoch 050/100 | Loss 0.8770 | Win/lose count 15.0/15.799999999999965 (-0.7999999999999652)
# Epoch 051/100 | Loss 0.7799 | Win/lose count 18.0/13.599999999999971 (4.400000000000029)
# Epoch 052/100 | Loss 0.8146 | Win/lose count 15.5/16.199999999999967 (-0.6999999999999673)
# Epoch 053/100 | Loss 0.9559 | Win/lose count 13.0/15.89999999999996 (-2.8999999999999595)
# Epoch 054/100 | Loss 0.9820 | Win/lose count 4.0/17.899999999999984 (-13.899999999999984)
# Epoch 055/100 | Loss 0.8251 | Win/lose count 23.0/16.599999999999984 (6.400000000000016)
# Epoch 056/100 | Loss 1.0157 | Win/lose count 18.0/15.099999999999964 (2.900000000000036)
# Epoch 057/100 | Loss 0.9375 | Win/lose count 19.5/14.499999999999964 (5.0000000000000355)
# Epoch 058/100 | Loss 0.9010 | Win/lose count 24.0/9.99999999999998 (14.00000000000002)
# Epoch 059/100 | Loss 1.0195 | Win/lose count 20.0/12.499999999999972 (7.500000000000028)
# Epoch 060/100 | Loss 1.0406 | Win/lose count 15.5/15.199999999999966 (0.30000000000003446)
# Epoch 061/100 | Loss 1.0263 | Win/lose count 17.5/13.899999999999967 (3.6000000000000334)
# Epoch 062/100 | Loss 1.0775 | Win/lose count 15.5/13.999999999999966 (1.5000000000000338)
# Epoch 063/100 | Loss 1.1393 | Win/lose count 12.5/16.399999999999963 (-3.899999999999963)
# Epoch 064/100 | Loss 1.0038 | Win/lose count 20.5/13.999999999999973 (6.500000000000027)
# Epoch 065/100 | Loss 1.2072 | Win/lose count 20.0/12.099999999999973 (7.900000000000027)
# Epoch 066/100 | Loss 1.1444 | Win/lose count 15.5/14.199999999999969 (1.300000000000031)
# Epoch 067/100 | Loss 1.0656 | Win/lose count 7.5/19.70000000000001 (-12.20000000000001)
# Epoch 068/100 | Loss 0.8773 | Win/lose count 4.5/18.9 (-14.399999999999999)
# Epoch 069/100 | Loss 0.8103 | Win/lose count 7.0/19.600000000000012 (-12.600000000000012)
# Epoch 070/100 | Loss 0.7682 | Win/lose count 24.5/11.599999999999975 (12.900000000000025)
# Epoch 071/100 | Loss 0.8742 | Win/lose count 9.0/20.900000000000034 (-11.900000000000034)
# Epoch 072/100 | Loss 0.7009 | Win/lose count 14.5/16.19999999999996 (-1.6999999999999602)
# Epoch 073/100 | Loss 0.9145 | Win/lose count 17.5/15.099999999999966 (2.400000000000034)
# Epoch 074/100 | Loss 0.7231 | Win/lose count 8.0/16.699999999999967 (-8.699999999999967)
# Epoch 075/100 | Loss 0.7489 | Win/lose count 17.0/14.999999999999964 (2.0000000000000355)
# Epoch 076/100 | Loss 0.6373 | Win/lose count 13.5/18.600000000000005 (-5.100000000000005)
# Epoch 077/100 | Loss 0.6265 | Win/lose count 10.0/17.099999999999973 (-7.099999999999973)
# Epoch 078/100 | Loss 0.4874 | Win/lose count 18.5/13.69999999999997 (4.800000000000029)
# Epoch 079/100 | Loss 0.8316 | Win/lose count 11.5/18.09999999999999 (-6.599999999999991)
# Epoch 080/100 | Loss 0.5466 | Win/lose count 9.0/18.800000000000004 (-9.800000000000004)
# Epoch 081/100 | Loss 0.5153 | Win/lose count 11.5/17.399999999999974 (-5.899999999999974)
# Epoch 082/100 | Loss 0.5107 | Win/lose count 24.0/14.199999999999976 (9.800000000000024)
# Epoch 083/100 | Loss 0.6545 | Win/lose count 8.0/16.09999999999996 (-8.099999999999959)
# Epoch 084/100 | Loss 0.6037 | Win/lose count 20.0/14.199999999999967 (5.800000000000033)
# Epoch 085/100 | Loss 0.4498 | Win/lose count 19.0/14.699999999999964 (4.300000000000036)
# Epoch 086/100 | Loss 0.7120 | Win/lose count 6.5/18.099999999999987 (-11.599999999999987)
# Epoch 087/100 | Loss 0.4482 | Win/lose count 9.5/16.89999999999997 (-7.39999999999997)
# Epoch 088/100 | Loss 0.5143 | Win/lose count 20.5/14.799999999999967 (5.700000000000033)
# Epoch 089/100 | Loss 0.7122 | Win/lose count 12.5/15.69999999999996 (-3.19999999999996)
# Epoch 090/100 | Loss 0.9586 | Win/lose count 11.0/15.999999999999961 (-4.999999999999961)
# Epoch 091/100 | Loss 0.7261 | Win/lose count 23.0/15.69999999999997 (7.300000000000029)
# Epoch 092/100 | Loss 0.6063 | Win/lose count 14.0/17.999999999999993 (-3.999999999999993)
# Epoch 093/100 | Loss 0.6020 | Win/lose count 9.5/16.399999999999963 (-6.899999999999963)
# Epoch 094/100 | Loss 0.5705 | Win/lose count 18.0/13.799999999999967 (4.200000000000033)
# Epoch 095/100 | Loss 0.5565 | Win/lose count 9.0/18.099999999999987 (-9.099999999999987)
# Epoch 096/100 | Loss 0.4280 | Win/lose count 7.5/19.000000000000007 (-11.500000000000007)
# Epoch 097/100 | Loss 0.3814 | Win/lose count 21.5/15.99999999999997 (5.50000000000003)
# Epoch 098/100 | Loss 0.5044 | Win/lose count 11.5/17.29999999999998 (-5.799999999999979)
# Epoch 099/100 | Loss 0.3474 | Win/lose count 14.5/17.199999999999974 (-2.6999999999999744)
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
# Evaluation
test(agent,env,epochs_test,prefix='cnn_test_explore')
HTML(display_videos('cnn_test_explore10.mp4'))

# %% [markdown]
# ***
# ***
# __BONUS question__ Use the expert DQN from the previous question to generate some winning games. Train a model that mimicks its behavior. Compare the performances.

# %% [markdown]
# ***
